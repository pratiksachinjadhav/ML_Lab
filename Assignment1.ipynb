# %%
import pandas as pd
import numpy as np
df = pd.read_csv('C:/Users/prati/Downloads/DatasetAssignment1.csv')
df.head()
# Out:
# C:\Users\prati\AppData\Local\Temp\ipykernel_11608\1977799454.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#                                  Movie Title Release Date  \
# 0                        10 Cloverfield Lane   2016-03-08
# 1  13 Hours: The Secret Soldiers of Benghazi   2016-01-15
# 2                                     2 Guns   2013-08-02
# 3                             21 Jump Street   2012-03-16
# 4                             22 Jump Street   2014-06-04
#
#                                        Wikipedia URL     Genre  \
# ...

# %%
to_drop = ['Director (2)']

df.drop(to_drop, inplace=True, axis=1)

# %%
df.head()
# Out:
#                                  Movie Title Release Date  \
# 0                        10 Cloverfield Lane   2016-03-08
# 1  13 Hours: The Secret Soldiers of Benghazi   2016-01-15
# 2                                     2 Guns   2013-08-02
# 3                             21 Jump Street   2012-03-16
# 4                             22 Jump Street   2014-06-04
#
#                                        Wikipedia URL     Genre  \
# 0  https://en.wikipedia.org/wiki/10_Cloverfield_Lane  Thriller
# 1  https://en.wikipedia.org/wiki/13_Hours:_The_Se...    Action
# 2               https://en.wikipedia.org/wiki/2_Guns    Action
# 3  https://en.wikipedia.org/wiki/21_Jump_Street_(...    Comedy
# 4       https://en.wikipedia.org/wiki/22_Jump_Street    Action
#
#         Director (1)                 Cast (1)           Cast (2)  \
# 0   Dan Trachtenberg  Mary Elizabeth Winstead       John Goodman
# 1        Michael Bay         James Badge Dale     John Krasinski
# ...

# %%
df['Movie Title'].is_unique
# Out:
# True

# %%
df = df.set_index('Movie Title')
df.head()
# Out:
#                                           Release Date  \
# Movie Title
# 10 Cloverfield Lane                         2016-03-08
# 13 Hours: The Secret Soldiers of Benghazi   2016-01-15
# 2 Guns                                      2013-08-02
# 21 Jump Street                              2012-03-16
# 22 Jump Street                              2014-06-04
#
#                                                                                Wikipedia URL  \
# Movie Title
# 10 Cloverfield Lane                        https://en.wikipedia.org/wiki/10_Cloverfield_Lane
# 13 Hours: The Secret Soldiers of Benghazi  https://en.wikipedia.org/wiki/13_Hours:_The_Se...
# 2 Guns                                                  https://en.wikipedia.org/wiki/2_Guns
# 21 Jump Street                             https://en.wikipedia.org/wiki/21_Jump_Street_(...
# 22 Jump Street                                  https://en.wikipedia.org/wiki/22_Jump_Street
#
# ...

# %%
df.loc['22 Jump Street']
# Out:
# Release Date                                       2014-06-04
# Wikipedia URL    https://en.wikipedia.org/wiki/22_Jump_Street
# Genre                                                  Action
# Director (1)                                        Phil Lord
# Cast (1)                                       Channing Tatum
# Cast (2)                                           Jonah Hill
# Cast (3)                                             Ice Cube
# Cast (4)                                                  NaN
# Cast (5)                                                  NaN
# Budget                                         $84,500,000.00
# Revenue                                       $331,300,000.00
# Name: 22 Jump Street, dtype: object

# %%
df.loc['22 Jump Street':, 'Budget '].head(10)
# Out:
# Movie Title
# 22 Jump Street             $84,500,000.00
# 300: Rise of an Empire    $110,000,000.00
# 42                         $40,000,000.00
# 71                          $8,100,000.00
# 90 Minutes in Heaven        $5,000,000.00
# A Good Day to Die Hard     $92,000,000.00
# A Haunted House             $2,500,000.00
# A Haunted House 2           $4,000,000.00
# A Long Way Down            $22,700,000.00
# A Most Violent Year        $20,000,000.00
# Name: Budget , dtype: object

# %%
df.columns
# Out:
# Index(['Release Date', 'Wikipedia URL', 'Genre', 'Director (1)', 'Cast (1)',
#        'Cast (2)', 'Cast (3)', 'Cast (4)', 'Cast (5)', 'Budget ', 'Revenue'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 508 entries, 10 Cloverfield Lane to Zoolander 2
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Release Date   508 non-null    object
#  1   Wikipedia URL  508 non-null    object
#  2   Genre          508 non-null    object
#  3   Director (1)   508 non-null    object
#  4   Cast (1)       508 non-null    object
#  5   Cast (2)       503 non-null    object
#  6   Cast (3)       485 non-null    object
#  7   Cast (4)       452 non-null    object
#  8   Cast (5)       389 non-null    object
#  9   Budget         508 non-null    object
#  10  Revenue        508 non-null    object
# dtypes: object(11)
# memory usage: 63.8+ KB

# %%
df.loc[df.isna().any(axis="columns")]
# Out:
#                           Release Date  \
# Movie Title
# 10 Cloverfield Lane         2016-03-08
# 22 Jump Street              2014-06-04
# 71                          2014-02-07
# 90 Minutes in Heaven        2015-09-11
# A Long Way Down             2014-02-10
# ...                                ...
# Victor Frankenstein         2015-11-25
# War Dogs                    2016-08-19
# When the Game Stands Tall   2014-08-04
# Whiplash                    2014-01-16
# Wild                        2014-08-29
#
#                                                                Wikipedia URL  \
# Movie Title
# 10 Cloverfield Lane        https://en.wikipedia.org/wiki/10_Cloverfield_Lane
# 22 Jump Street                  https://en.wikipedia.org/wiki/22_Jump_Street
# 71                              https://en.wikipedia.org/wiki/%252771_(film)
# 90 Minutes in Heaven       https://en.wikipedia.org/wiki/90_Minutes_in_He...
# ...

# %%
df.to_csv("C:/Users/prati/Downloads/Assign1data_cleansed.csv", index=False)
